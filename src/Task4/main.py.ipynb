# %%
import csv
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect("./shipment_database.db")
curr = con.cursor()

for row in curr.execute("select * from sqlite_master where type='table';"):
    print(row)
# Out:
# ('table', 'product', 'product', 2, 'CREATE TABLE product\n(\n    id   INTEGER not null primary key,\n    name TEXT    not null unique\n)')
# ('table', 'shipment', 'shipment', 4, 'CREATE TABLE shipment\n(\n    id          INTEGER not null primary key,\n    product_id  INTEGER not null references product,\n    quantity    INTEGER not null,\n    origin      TEXT    not null,\n    destination TEXT    not null\n)')

# %%
res = curr.execute("select * from product")
res.fetchall()
# Out:
# []

# %%
res = curr.execute("select * from shipment")
res.fetchall()
# Out:
# []

# %%
data_0 = pd.read_csv("data/shipping_data_0.csv")
data_0
# Out:
#                          origin_warehouse  \
# 0    d5566b15-b071-4acf-8e8e-c98433083b2d
# 1    c42f0de8-b4f0-4167-abd1-ae79e5e18eea
# 2    b145f396-de9b-42f1-9cc9-f5b52c3a941c
# 3    f4372224-759f-43b3-bc83-ca6106bba1af
# 4    49d0edae-9091-41bb-a08d-ab1c66bd08d5
# ..                                    ...
# 105  d2ee1b75-2218-4753-9487-dcca23d667c6
# 106  6a6d3fce-c5aa-4154-a6a3-b56cb41f709f
# 107  b19cec0d-357e-4c6b-9257-8be52b1c71b5
# 108  d2a2460e-00d1-41f2-84cc-eba01eb88d75
# 109  75891066-59b4-437b-951f-ec553fb26b94
#
#                         destination_store            product  on_time  \
# 0    50d33715-4c77-4dd9-8b9d-ff1ca372a2a2             lotion     True
# 1    172eb8f3-1033-4fb6-b66b-d0df09df3161            windows     True
# 2    65e4544d-42ae-4751-9580-bdcb90e5fcda               skis     True
# 3    745bee4e-710c-4538-8df1-5c146e1092a6              bikes     True
# 4    425b7a1a-b744-4c6b-898e-d424dd8cf18e              candy    False
# ...

# %%
data_1 = pd.read_csv("data/shipping_data_1.csv")
data_1
# Out:
#                       shipment_identifier       product  on_time
# 0    449263b4-6c93-4f19-8b6a-0d99a29fc637         pants    False
# 1    449263b4-6c93-4f19-8b6a-0d99a29fc637         pants    False
# 2    449263b4-6c93-4f19-8b6a-0d99a29fc637         pants    False
# 3    449263b4-6c93-4f19-8b6a-0d99a29fc637     keyboards    False
# 4    449263b4-6c93-4f19-8b6a-0d99a29fc637     keyboards    False
# ..                                    ...           ...      ...
# 105  c2237ca1-b7e3-40ab-b798-e1ea469301dc     keyboards     True
# 106  cfa8a834-54bd-4f47-99ca-8912df32913b  animal masks    False
# 107  cfa8a834-54bd-4f47-99ca-8912df32913b     furniture    False
# 108  cfa8a834-54bd-4f47-99ca-8912df32913b     furniture    False
# 109  cfa8a834-54bd-4f47-99ca-8912df32913b     furniture    False
#
# [110 rows x 3 columns]

# %%
data_2 = pd.read_csv("data/shipping_data_2.csv")
data_2
# Out:
#                      shipment_identifier  \
# 0   449263b4-6c93-4f19-8b6a-0d99a29fc637
# 1   76e5b84a-9d09-4efb-8b43-a0c932b958bb
# 2   b541a47d-89b1-4805-97d0-1988832321f1
# 3   3fc6b63d-27b4-408c-b3b3-e8e94a45b079
# 4   491ee4e8-be80-4f52-802b-d8fe1a6bd487
# 5   22768e96-0dad-40d2-8204-3921263c3826
# 6   f20bbd93-1312-4f70-b257-654056412ec5
# 7   192cc6dc-4799-4247-a228-6d198675c00b
# 8   e31e22c1-5395-43d8-8a0a-79396d627f66
# 9   6060c04b-921b-4bf9-b2d3-40e57257e5c6
# 10  d2306016-fe82-41f8-a8e1-b06812007036
# 11  3433af6d-4857-4dfa-88d6-5dcd2a2fce6b
# 12  2fcf115d-068f-4a65-b443-2c5c6fe33fe0
# 13  a39dad1a-4b34-4f50-879e-08bec70d2b36
# 14  4fc4c56e-9e44-432a-9d1c-4219271a7844
# 15  c9cf4b47-8a85-488d-b33f-d1f921552ea0
# 16  2b0bddcd-d73c-4ba6-b26e-aaa785d50be7
# 17  36117159-bb83-4b02-b1d0-07f68fe03be6
# 18  c2237ca1-b7e3-40ab-b798-e1ea469301dc
# 19  cfa8a834-54bd-4f47-99ca-8912df32913b
#
#                         origin_warehouse  \
# 0   bb75bf7d-c008-4267-bf92-6089cff5fe56
# ...

# %%
for shipment in data_0.iterrows():
    print(shipment)
# Out:
# (0, origin_warehouse     d5566b15-b071-4acf-8e8e-c98433083b2d
# destination_store    50d33715-4c77-4dd9-8b9d-ff1ca372a2a2
# product                                            lotion
# on_time                                              True
# product_quantity                                       59
# driver_identifier    d8da0460-cf39-4f38-9fff-6c9b4e344d8a
# Name: 0, dtype: object)
# (1, origin_warehouse     c42f0de8-b4f0-4167-abd1-ae79e5e18eea
# destination_store    172eb8f3-1033-4fb6-b66b-d0df09df3161
# product                                           windows
# on_time                                              True
# product_quantity                                       28
# driver_identifier    293ccaec-6592-4f04-aae5-3e238fe62614
# Name: 1, dtype: object)
# (2, origin_warehouse     b145f396-de9b-42f1-9cc9-f5b52c3a941c
# destination_store    65e4544d-42ae-4751-9580-bdcb90e5fcda
# product                                              skis
# ...

# %%
con.close()

# %%
with open("./data/shipping_data_1.csv") as file_1:
    with open("./data/shipping_data_2.csv") as file_2:
        shipments = {}
        for i, row in enumerate(csv.reader(file_2)):
            if i > 0:
                shipments[row[0]] = [row[1], row[2], {}]
        # print(shipments)
        for i, row in enumerate(csv.reader(file_1)):
            if i > 0:
                # print(shipments[row[0]])
                shipments[row[0]][2][row[1]] =  shipments[row[0]][2].get(row[1], 0) + 1
        print(shipments.items())
# Out:
# dict_items([('449263b4-6c93-4f19-8b6a-0d99a29fc637', ['bb75bf7d-c008-4267-bf92-6089cff5fe56', '5e9405de-a078-4b00-99c6-96564568b63c', {'pants': 3, 'keyboards': 2}]), ('76e5b84a-9d09-4efb-8b43-a0c932b958bb', ['372fd2b1-b2a7-4553-b6d7-426a1bc88e56', 'e34973c8-9ca9-4a06-b497-7a8b49625fc2', {'baby food': 1}]), ('b541a47d-89b1-4805-97d0-1988832321f1', ['469d957f-28ef-4eac-956a-d2a42b06d3ab', 'fcadc756-61e9-41bb-871b-d3546c5aa981', {'paint': 3, 'water bottles': 2}]), ('3fc6b63d-27b4-408c-b3b3-e8e94a45b079', ['cd140190-a53b-4660-a5b4-cc844a6506f0', '89ba200c-ca90-443a-b64f-397bce091eae', {'journals': 1, 'lotion': 4, 'keyboards': 4}]), ('491ee4e8-be80-4f52-802b-d8fe1a6bd487', ['c6addf8b-eea6-43b8-9040-b5620b1a0d99', '7aebe820-8478-4a29-a606-7c59af677e24', {'lotion': 3, 'keys': 3}]), ('22768e96-0dad-40d2-8204-3921263c3826', ['5d64f731-cb01-4992-a27c-a6e1342f4913', 'd57d76d8-7dca-4ee4-84c0-1745fb4c8779', {'lamps': 3, 'hydroponic equipment': 1, 'balloons': 2}]), ('f20bbd93-1312-4f70-b257-654056
# ...
